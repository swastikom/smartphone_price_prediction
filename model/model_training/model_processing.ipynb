# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../clean_dataset/clean.csv')
df = df[['os','Number of Sim','Processor Name','Processor No. of Cores','Ram Size(GB)','Rom Size(GB)','Battery Capacity','Display Size(inches)','Rear Camera 1','Front Camera','External Card Support','Brand','price']]
df
# Out:
#               os  Number of Sim       Processor Name  Processor No. of Cores  \
# 0    Android v13              2    Snapdragon 8 Gen2                       8
# 1    Android v12              2       Snapdragon 695                       8
# 2    Android v13              2          Exynos 1330                       8
# 3    Android v12              2      Snapdragon  695                       8
# 4    Android v13              2       Dimensity 1080                       8
# ..           ...            ...                  ...                     ...
# 874  Android v12              2    Snapdragon 8 Gen1                       8
# 875  Android v11              2     Snapdragon  480+                       8
# 876  Android v12              2       Dimensity 8100                       8
# 877  Android v12              2       Snapdragon 695                       8
# 878  Android v12              2  Octa Core Processor                       8
#
#      Ram Size(GB)  Rom Size(GB)  Battery Capacity  Display Size(inches)  \
# 0            12.0         256.0            5000.0                  6.70
# 1             6.0         128.0            5000.0                  6.59
# 2             4.0          64.0            5000.0                  6.60
# 3             6.0         128.0            5000.0                  6.55
# 4             6.0         128.0            5000.0                  6.70
# ..            ...           ...               ...                   ...
# 874           8.0         128.0            5000.0                  6.67
# 875           6.0         128.0            5000.0                  6.50
# 876           8.0         256.0            5080.0                  6.60
# 877           6.0         128.0            5000.0                  6.80
# 878           8.0         128.0            5000.0                  6.50
#
#      Rear Camera 1  Front Camera  External Card Support     Brand  price
# 0               50            16                      0   OnePlus  54999
# 1               64            16                      1   OnePlus  19989
# 2               50            13                      1   Samsung  16499
# 3               50            16                      1  Motorola  14999
# 4              108            16                      0    Realme  24999
# ..             ...           ...                    ...       ...    ...
# 874             64            16                      0  Motorola  34990
# 875             48             8                      1     Honor  14990
# 876             64            16                      0      POCO  28990
# 877            108            32                      1  Motorola  19990
# 878             64            32                      1   Samsung  24990
#
# [879 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder

os_encoder = LabelEncoder()
brand_encoder = LabelEncoder()
processor_encoder = LabelEncoder()

os_encoder.fit(df['os'])
brand_encoder.fit(df['Brand'])
processor_encoder.fit(df['Processor Name'])

df['os'] = os_encoder.transform(df['os'])
df['Brand'] = brand_encoder.transform(df['Brand'])
df['Processor Name'] = processor_encoder.transform(df['Processor Name']) 

df
# Out:
#      os  Number of Sim  Processor Name  Processor No. of Cores  Ram Size(GB)  \
# 0     4              2             187                       8          12.0
# 1     3              2             169                       8           6.0
# 2     4              2              54                       8           4.0
# 3     3              2             125                       8           6.0
# 4     4              2              23                       8           6.0
# ..   ..            ...             ...                     ...           ...
# 874   3              2             186                       8           8.0
# 875   2              2             117                       8           6.0
# 876   3              2              35                       8           8.0
# 877   3              2             169                       8           6.0
# 878   3              2             107                       8           8.0
#
#      Rom Size(GB)  Battery Capacity  Display Size(inches)  Rear Camera 1  \
# 0           256.0            5000.0                  6.70             50
# 1           128.0            5000.0                  6.59             64
# 2            64.0            5000.0                  6.60             50
# 3           128.0            5000.0                  6.55             50
# 4           128.0            5000.0                  6.70            108
# ..            ...               ...                   ...            ...
# 874         128.0            5000.0                  6.67             64
# 875         128.0            5000.0                  6.50             48
# 876         256.0            5080.0                  6.60             64
# 877         128.0            5000.0                  6.80            108
# 878         128.0            5000.0                  6.50             64
#
#      Front Camera  External Card Support  Brand  price
# 0              16                      0     25  54999
# 1              16                      1     25  19989
# 2              13                      1     33  16499
# 3              16                      1     20  14999
# 4              16                      0     30  24999
# ..            ...                    ...    ...    ...
# 874            16                      0     20  34990
# 875             8                      1      8  14990
# 876            16                      0     28  28990
# 877            32                      1     20  19990
# 878            32                      1     33  24990
#
# [879 rows x 13 columns]

# %%
X = df.drop(['Brand', 'price'], axis=1)
y_price = df['price']
X
# Out:
#      os  Number of Sim  Processor Name  Processor No. of Cores  Ram Size(GB)  \
# 0     4              2             187                       8          12.0
# 1     3              2             169                       8           6.0
# 2     4              2              54                       8           4.0
# 3     3              2             125                       8           6.0
# 4     4              2              23                       8           6.0
# ..   ..            ...             ...                     ...           ...
# 874   3              2             186                       8           8.0
# 875   2              2             117                       8           6.0
# 876   3              2              35                       8           8.0
# 877   3              2             169                       8           6.0
# 878   3              2             107                       8           8.0
#
#      Rom Size(GB)  Battery Capacity  Display Size(inches)  Rear Camera 1  \
# 0           256.0            5000.0                  6.70             50
# 1           128.0            5000.0                  6.59             64
# 2            64.0            5000.0                  6.60             50
# 3           128.0            5000.0                  6.55             50
# 4           128.0            5000.0                  6.70            108
# ..            ...               ...                   ...            ...
# 874         128.0            5000.0                  6.67             64
# 875         128.0            5000.0                  6.50             48
# 876         256.0            5080.0                  6.60             64
# 877         128.0            5000.0                  6.80            108
# 878         128.0            5000.0                  6.50             64
#
#      Front Camera  External Card Support
# 0              16                      0
# 1              16                      1
# 2              13                      1
# 3              16                      1
# 4              16                      0
# ..            ...                    ...
# 874            16                      0
# 875             8                      1
# 876            16                      0
# 877            32                      1
# 878            32                      1
#
# [879 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# Instantiate and train a GradientBoostingRegressor for price prediction
while True:
    from sklearn.ensemble import GradientBoostingRegressor
    X_price_train, X_price_test, y_price_train, y_price_test = train_test_split(X, y_price, test_size=0.2)
    price_gbr = GradientBoostingRegressor(n_estimators=200, random_state=50)
    price_gbr.fit(X_price_train, y_price_train)
    score = price_gbr.score(X_price_test, y_price_test)
    print('Bad score : ')
    print(score)
    if 0.9 < score:
        break
    
print(score)


# Make predictions
# Out:
# Bad score :
# 0.894852684194082
# Bad score :
# 0.7592393188656696
# Bad score :
# 0.21736500896582034
# Bad score :
# 0.7805126433809587
# Bad score :
# 0.18866846856622133
# Bad score :
# 0.7930603577710582
# Bad score :
# 0.6095960009704486
# Bad score :
# 0.16170342140371186
# Bad score :
# 0.15128690904756714
# Bad score :
# 0.8634824553066216
# Bad score :
# 0.16986838851066755
# Bad score :
# 0.8102651244198413
# Bad score :
# 0.13386743374955534
# Bad score :
# 0.7526535679792274
# Bad score :
# -4.55120301926834
# Bad score :
# 0.7556713675473907
# Bad score :
# 0.21202840518263433
# Bad score :
# 0.3276350751822429
# Bad score :
# 0.19667160706400144
# Bad score :
# 0.6723263165092269
# Bad score :
# -0.21208423154105427
# Bad score :
# 0.6648023112946493
# Bad score :
# 0.17238508117378248
# Bad score :
# -0.027072171516817622
# Bad score :
# 0.3777403896961483
# Bad score :
# 0.8366888480908288
# Bad score :
# 0.17150954590560097
# Bad score :
# 0.6673748675591611
# Bad score :
# 0.25836150784043377
# Bad score :
# 0.1406070454118753
# Bad score :
# 0.7587304330069912
# Bad score :
# 0.1887535142358514
# Bad score :
# 0.8370844634925844
# Bad score :
# 0.17291934529533648
# Bad score :
# -1.3499684214317247
# Bad score :
# 0.81452589998227
# Bad score :
# 0.21106734814010386
# Bad score :
# 0.21079932286281777
# Bad score :
# 0.321704073127706
# Bad score :
# 0.8539766506476193
# Bad score :
# 0.23458276298642233
# Bad score :
# 0.8474747577861816
# Bad score :
# 0.08085322127059114
# Bad score :
# 0.3027621115995752
# Bad score :
# 0.8323954510889996
# Bad score :
# 0.8348024461513187
# Bad score :
# 0.280473395007208
# Bad score :
# 0.41526819462525755
# Bad score :
# -0.24897944058211685
# Bad score :
# 0.7824658421123307
# Bad score :
# 0.1934920572752088
# Bad score :
# 0.8264845305962509
# Bad score :
# 0.7821754868047384
# Bad score :
# 0.2171126285276085
# Bad score :
# 0.7024044887559471
# Bad score :
# 0.7415373917616053
# Bad score :
# -1.2480471041280343
# Bad score :
# 0.23545208365406545
# Bad score :
# 0.807877097221793
# Bad score :
# 0.725709155355251
# Bad score :
# 0.12669629888563128
# Bad score :
# 0.3780855878396311
# Bad score :
# 0.13281953807428437
# Bad score :
# 0.715994266879239
# Bad score :
# 0.8272547777631913
# Bad score :
# 0.8048560410458387
# Bad score :
# 0.15022668902313996
# Bad score :
# -0.09203285232828251
# Bad score :
# 0.20551586270521416
# Bad score :
# 0.7936030265631122
# Bad score :
# -0.04852476542547057
# Bad score :
# 0.3658617535609151
# Bad score :
# 0.17363025525153764
# Bad score :
# 0.34998621120382667
# Bad score :
# 0.8533985763282844
# Bad score :
# 0.7200597868153558
# Bad score :
# 0.21334266574375926
# Bad score :
# 0.6528323839398558
# Bad score :
# 0.8594762821594352
# Bad score :
# 0.31000067079335614
# Bad score :
# 0.1748419369073244
# Bad score :
# 0.3024315307866047
# Bad score :
# 0.6464375198731203
# Bad score :
# 0.800026271272034
# Bad score :
# 0.7174798286562962
# Bad score :
# -0.38145498085212703
# Bad score :
# 0.3071713236193998
# Bad score :
# 0.7783779946499584
# Bad score :
# 0.18914589954527006
# Bad score :
# 0.668901887795454
# Bad score :
# 0.18622002939729798
# Bad score :
# 0.20387200852713028
# Bad score :
# 0.1973898736381191
# Bad score :
# 0.7634294830674196
# Bad score :
# 0.14490689147974312
# Bad score :
# 0.18293467273717956
# Bad score :
# 0.4042783575073179
# Bad score :
# 0.361970805785072
# Bad score :
# 0.8680242556661816
# Bad score :
# 0.74907641335811
# Bad score :
# 0.9034257064986518
# 0.9034257064986518

# %%
import pickle
import numpy as np

with open('../models/price_model.pkl', 'wb') as file:
    pickle.dump((price_gbr, os_encoder, processor_encoder), file)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predicted prices using the trained Gradient Boosting Regressor
predicted_prices_train = price_gbr.predict(X_price_train)

# Sort the actual and predicted prices based on actual prices
sorted_indices = np.argsort(y_price_train)
sorted_actual_prices = y_price_train.iloc[sorted_indices]
sorted_predicted_prices = predicted_prices_train[sorted_indices]

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(sorted_actual_prices, sorted_predicted_prices,
            color='red', label='Predicted',marker='+')
plt.plot(sorted_actual_prices, sorted_actual_prices,
         color='blue', linestyle=':', label='Ideal')

plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Regression Line: Actual vs. Predicted Prices (Training Samples)')
plt.legend()
plt.grid(True)
plt.show()

# %%
df['price'].max()
# Out:
# 650000

# %%
bins = [0, 20000, 50000, 100000, 200000]  # Ranges: 0-10, 11-20, 21-30

# Create the histogram
plt.hist(df['price'], bins=bins, edgecolor='black')
plt.hist(predicted_prices_train, bins=bins, edgecolor='black', color='red')
# Customize the plot
plt.title('Number Range Distribution')
plt.xlabel('Number Ranges')
plt.ylabel('Frequency')

# Add labels to the x-axis ticks
plt.xticks(bins)

# Display the plot
plt.show()

# %%
import seaborn as sns
correlations = df.corr()['Brand']
# Create a bar plot to visualize correlations
plt.figure(figsize=(10, 6))
sns.barplot(x=correlations.index, y=correlations.values)
plt.xticks(rotation=45)
plt.title("Correlations between Features and Target")
plt.xlabel("Features")
plt.ylabel("Correlation")
plt.show()

# %%
df.head(5)
# Out:
#    os  Number of Sim  Processor Name  Processor No. of Cores  Ram Size(GB)  \
# 0   4              2             187                       8          12.0
# 1   3              2             169                       8           6.0
# 2   4              2              54                       8           4.0
# 3   3              2             125                       8           6.0
# 4   4              2              23                       8           6.0
#
#    Rom Size(GB)  Battery Capacity  Display Size(inches)  Rear Camera 1  \
# 0         256.0            5000.0                  6.70             50
# 1         128.0            5000.0                  6.59             64
# 2          64.0            5000.0                  6.60             50
# 3         128.0            5000.0                  6.55             50
# 4         128.0            5000.0                  6.70            108
#
#    Front Camera  External Card Support  Brand  price
# 0            16                      0     25  54999
# 1            16                      1     25  19989
# 2            13                      1     33  16499
# 3            16                      1     20  14999
# 4            16                      0     30  24999

# %%
df2 = df[['Processor Name','Battery Capacity','Front Camera', 'Display Size(inches)','Number of Sim', 'Brand']]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

X = df2.drop('Brand', axis=1)
y = df2['Brand']

while True:
    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.1, random_state=45)

    # Initialize the Random Forest classifier
    clf = RandomForestClassifier()

    # Train the classifier on the training data
    clf.fit(X_train, y_train)

    # Calculate the accuracy of the model on the test data
    accuracy = clf.score(X_test, y_test)
    y_pred = clf.predict(X_test)
    print('Current accuracy:', accuracy)

    # Check if the accuracy is greater than 0.9
    if accuracy > 0.7:
        break
# Out:
# Current accuracy: 0.7045454545454546

# %%
import pickle


# Export the model and label encoder using pickle
with open('../models/brand_model.pkl', 'wb') as file:
    pickle.dump((clf, brand_encoder, processor_encoder), file)

# %%
plt.figure(figsize=(10, 6))

plt.hist(y_test, alpha=0.5, label='Test Values', bins=20, color='blue')
plt.hist(y_pred, alpha=0.5, label='Predicted Values', bins=20, color='green')

plt.xlabel('Brand')
plt.ylabel('Frequency')
plt.title('Histogram of Test Values and Predicted Values')
plt.legend()
plt.show()
